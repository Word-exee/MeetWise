# %%
import json
import os
import csv
import requests
import pprint
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import os.path
import joblib
from joblib import memory
import googlemaps 
import pandas as pd

# supress warnings
import warnings 
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
import re
import string
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score
# Out:
# d:\anaconda\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 12
#      10 from mpl_toolkits.basemap import Basemap
#      11 import os.path
# ---> 12 import joblib
#      13 from joblib import memory
#      14 import googlemaps
#
# File d:\anaconda\Lib\site-packages\joblib\__init__.py:113
#     109 __version__ = '1.2.0'
#     112 import os
# --> 113 from .memory import Memory, MemorizedResult, register_store_backend
#     114 from .logger import PrintTime
#     115 from .logger import Logger
#
# File d:\anaconda\Lib\site-packages\joblib\memory.py:32
#      30 from .func_inspect import format_signature
#      31 from .logger import Logger, format_time, pformat
# ---> 32 from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#      35 FIRST_LINE_TEXT = "# first line:"
#      37 # TODO: The following object should have a data store object as a sub
#      38 # object, and the interface to persist and query should be separated in
#      39 # the data store.
#    (...)
#      46 # TODO: Same remark for the logger, and probably use the Python logging
#      47 # mechanism.
#
# File d:\anaconda\Lib\site-packages\joblib\_store_backends.py:17
#      15 from .backports import concurrency_safe_rename
#      16 from .disk import mkdirp, memstr_to_bytes, rm_subdirs
# ---> 17 from . import numpy_pickle
#      19 CacheItemInfo = collections.namedtuple('CacheItemInfo',
#      20                                        'path size last_access')
#      23 def concurrency_safe_write(object_to_write, filename, write_func):
#
# File d:\anaconda\Lib\site-packages\joblib\numpy_pickle.py:13
#      10 import io
#      11 from pathlib import Path
# ---> 13 from .compressor import lz4, LZ4_NOT_INSTALLED_ERROR
#      14 from .compressor import _COMPRESSORS, register_compressor, BinaryZlibFile
#      15 from .compressor import (ZlibCompressorWrapper, GzipCompressorWrapper,
#      16                          BZ2CompressorWrapper, LZMACompressorWrapper,
#      17                          XZCompressorWrapper, LZ4CompressorWrapper)
#
# File d:\anaconda\Lib\site-packages\joblib\compressor.py:18
#      15     bz2 = None
#      17 try:
# ---> 18     import lz4
#      19     from lz4.frame import LZ4FrameFile
#      20 except ImportError:
#
# File d:\anaconda\Lib\site-packages\lz4\__init__.py:13
#       1 # Although the canonical way to get the package version is using pkg_resources
#       2 # as below, this turns out to be very slow on systems with lots of packages.
#       3 # So, until that is remedied, we'll import the version from a local file
#    (...)
#      10 #     # package is not installed
#      11 #     pass
# ---> 13 from .version import version as __version__
#      14 from ._version import (  # noqa: F401
#      15     library_version_number,
#      16     library_version_string,
#      17 )
#      19 VERSION = __version__
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1032, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1130, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
# Declaring API Keys Used
places_api_web_service =  'AIzaSyCztZNSls0oSkmLXe3FNjLilCA7xIp4Ork'
geocoding_api = 'AIzaSyA3cUamax65N5NLxuSF4EXuV6DGGMxDNXQ'

# %%
def latlong(loc1):
    current_loc = loc1.replace(" ", "+")

    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address=" + current_loc + "&key=" + geocoding_api

    response1 = requests.get(geocode_url)
    data = json.loads(response1.text)

    current_lat = data['results'][0]['geometry']['location']['lat']
    current_long = data['results'][0]['geometry']['location']['lng']
    return current_lat, current_long

# %%
# Declaring Global Variables Used
pause = 0.1
max_api_requests = 150000 
api_requests_count = 0
pp = pprint.PrettyPrinter(indent=4)

# %%
number_of_users=int(input())
Location_array=[]
for j in range(number_of_users):
    Location_array.append(input())
typ=input()

# %%
# latlng="28.621271,77.061325"
# radius=5
radius = 3000
current_lat=0
current_long=0
for j in range(number_of_users):
    current_lat1,current_long1=latlong(Location_array[j])
    current_lat+=current_lat1
    current_long+=current_long1
    
    
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="
if (api_requests_count < max_api_requests):  
    time.sleep(pause)
    api_requests_count += 1
    reverse_geocode_url = url + str(current_lat/number_of_users) + "," + str(current_long/number_of_users)+ "&radius=" + str(radius) + "&type="+str(typ) + "&key=" + places_api_web_service
    response = requests.get(reverse_geocode_url)
    data = response.json().get("results",{})

# %%
if len(data) > 0:
        resp_address = data
        name = []
        types = []
        rating=[]
        lat=[]
        lng=[]
        rating=[]
        totnb_reviews=[]
        place_id_array=[]
        vicinity=[]
        review=[]
        
        
        for i in range (0, len(resp_address)):
            place_idd=resp_address[i]['place_id']
            params = {
            "place_id": place_idd,
            "key": 'AIzaSyCztZNSls0oSkmLXe3FNjLilCA7xIp4Ork',
            "fields": "reviews"  # Request specific fields to minimize data usage
            }
            base_url = "https://maps.googleapis.com/maps/api/place/details/json"
            response = requests.get(base_url, params=params)
            place_details = response.json().get("result", {})
            
            rat = place_details.get("rating")
            rating.append(rat)
            
            rev=place_details.get("reviews", [])
            revrat=[]
            for j in range(len(rev)):
                revrat.append(rev[j]['text'])
                revrat.append('&&&&&')
            review.append(revrat)
            name.append(str(resp_address[i]['name']))
            types.append (resp_address[i]['types'])
            lat.append(resp_address[i]['geometry']['location']['lat'])
            lng.append (resp_address[i]['geometry']['location']['lng'])
            place_id_array.append(place_idd)
            vicinity.append (resp_address[i]['vicinity'])

# %%
with open('cache_file.csv', 'w',encoding='utf-8') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    heading = ["name","vicinity", "type",'latitude','longitude','rating','reviews','place_id','Sentiment Ratio']
    wr.writerow(heading)
    for i in range(len(types)):
        wr.writerow([name[i],vicinity[i],types[i],lat[i],lng[i],rating[i],review[i],place_id_array[i]])
myfile.close()

# %%
write=pd.read_csv('cache_file.csv')
write.head(20)
# Out:
#                                            name  \
# 0                                     New Delhi
# 1                                    Manraj B&b
# 2                                   Time Centre
# 3                                  Deluxe Store
# 4                             Softdot Education
# 5                                Skylink Suites
# 6   Tanishq Jewellery - Delhi - South Extension
# 7                  iExpress Building Confidence
# 8                     Red Maple Bed & Breakfast
# 9                               Bhatia Musicals
# 10                          Rajesh Pratap Singh
# 11                              Hotel Park Land
# 12                               Slice Of Italy
# 13                              Wills Lifestyle
# 14                                     Woodland
# 15                                Defence Store
# 16                             Khanna Jewellers
# 17                         Edwise International
# 18                            3D Tattoos Studio
# 19                               Defence Colony
#
#                                              vicinity  \
# 0                                           New Delhi
# 1                L 1/2, South Extension II, New Delhi
# 2   81-A, Khanna Market Road, Nehru Stadium, Lodi ...
# 3                       41, Defence Colony, New Delhi
# 4   K-16, Mahatma Gandhi Road, South Extension I, ...
# 5                H, 7, South Extension I, South Delhi
# 6   F-44, Mahatma Gandhi Road, South Extension I, ...
# 7   F3, BLOCK-F, 108, Charmwood Village, Surajkund...
# 8                          49, Amrit Nagar, New Delhi
# 9   Shop No-2, Lodhi Road, New Khanna Market, New ...
# 10     Shop No.4, Main Market, Lodi Colony, New Delhi
# 11  C-169, Chandan Vithi Road, Block C, Defence Co...
# 12  147, Lodhi Road, Meharchand Market, Lodhi Esta...
# 13  Shop No. F, 41, Mahatma Gandhi Road, South Ext...
# 14                 E 11, South Extension 2, New Delhi
# 15          38, Defence Colony Main Market, New Delhi
# 16  F - 39, Mahatma Gandhi Road, South Extension I...
# 17  N-13, Opp. Flyover Above Punjab National Bank,...
# 18                    454A, Defence Colony, New Delhi
# 19                                     Defence Colony
#
#                                                  type   latitude  longitude  \
# 0                           ['locality', 'political']  28.613930  77.208828
# 1   ['lodging', 'point_of_interest', 'establishment']  28.570091  77.219313
# 2     ['point_of_interest', 'store', 'establishment']  28.581594  77.220314
# 3   ['drugstore', 'department_store', 'health', 'p...  28.573521  77.230493
# 4              ['point_of_interest', 'establishment']  28.569612  77.218016
# 5   ['lodging', 'point_of_interest', 'establishment']  28.571354  77.221601
# 6   ['jewelry_store', 'point_of_interest', 'store'...  28.569237  77.218525
# 7              ['point_of_interest', 'establishment']  28.570802  77.218437
# 8   ['lodging', 'point_of_interest', 'establishment']  28.573536  77.219636
# 9     ['point_of_interest', 'store', 'establishment']  28.580597  77.220816
# 10  ['point_of_interest', 'clothing_store', 'store...  28.584696  77.223349
# 11  ['lodging', 'point_of_interest', 'establishment']  28.572705  77.232531
# 12  ['bakery', 'restaurant', 'point_of_interest', ...  28.581887  77.227008
# 13  ['clothing_store', 'point_of_interest', 'store...  28.569183  77.219159
# 14  ['shoe_store', 'point_of_interest', 'store', '...  28.567755  77.220641
# 15  ['grocery_or_supermarket', 'home_goods_store',...  28.573641  77.230441
# 16  ['jewelry_store', 'point_of_interest', 'store'...  28.569158  77.219546
# 17             ['point_of_interest', 'establishment']  28.568873  77.223344
# 18    ['point_of_interest', 'store', 'establishment']  28.572339  77.230091
# 19  ['sublocality_level_1', 'sublocality', 'politi...  28.573354  77.232650
#
#     rating                                            reviews  \
# 0      NaN                                                 []
# 1      NaN                                                 []
# 2      NaN  ['Very dishonest. Initially he told the price ...
# 3      NaN  ['It took them 5 mins to decide if they have p...
# 4      NaN  ['Fake institute, they are totally play with t...
# 5      NaN  ['Premium family hotel with excellent service ...
# 6      NaN  ['Dear Joyti,\n\nYour guidance in navigating t...
# 7      NaN  ["It's a shoppers paradise. The place is well ...
# 8      NaN  ['Commuting with a cab is difficult. Rooms are...
# 9      NaN  ['Beware, avoid this store at all costs. The o...
# 10     NaN  ['I would not contact them as they wasted a lo...
# 11     NaN  ['Excellent location\nValue for money 4/5', '&...
# 12     NaN  ['The joint actually serves as a delivery depo...
# 13     NaN  ["Though products are good but didn't find lat...
# 14     NaN  ['Good service and good infrastructure and goo...
# 15     NaN  ["Hey fellow flavor enthusiasts! Let me introd...
# 16     NaN  ['This is a jewellery shop where the customer ...
# 17     NaN  ['I really had a great experience here in Edwi...
# 18     NaN  ["Gupt is outstanding. He is not just a tattoo...
# 19     NaN                                                 []
#
#                        place_id  Sentiment Ratio
# 0   ChIJLbZ-NFv9DDkRzk0gTkm3wlI              NaN
# 1   ChIJg3IIvF3iDDkRhZxTyMun76c              NaN
# 2   ChIJ922KgfTiDDkRoMugs1Sykcw              NaN
# 3   ChIJZ1LNSVfiDDkR2cVBaKkA9XU              NaN
# 4   ChIJqcjMwoMdDTkRlvx8423M8u8              NaN
# 5   ChIJn4gzI1ziDDkR9O77oIjkc7E              NaN
# 6   ChIJEV_DCl3iDDkREH0rfSYLvD4              NaN
# 7   ChIJK283Q63jDDkRpG7c_7AdTGE              NaN
# 8   ChIJAQDARl7iDDkRPMvE7jjAm4s              NaN
# 9   ChIJ922KgfTiDDkR1-hi5sK0KJ0              NaN
# 10  ChIJK2vn4PPiDDkR0vGIG4wO2MI              NaN
# 11  ChIJEV_DCl3iDDkRt2mFpWF8Trw              NaN
# 12  ChIJI0-4D_fiDDkRKRJCoRd85YA              NaN
# 13  ChIJAQAAwF7iDDkRgojJxKBM9Gk              NaN
# 14  ChIJAQAAwGviDDkRfpCn2Gp0u5A              NaN
# 15  ChIJmW3JSVfiDDkRrIIAdSNjnZ0              NaN
# 16  ChIJ37xQvkLiDDkRiYzvlwR14xQ              NaN
# 17  ChIJq6qqGoQdDTkRJMQ-qvynXME              NaN
# 18  ChIJVVVVFVHiDDkR6ebQvdBma3w              NaN
# 19  ChIJQyZfKFHiDDkRxoP07W2fGcQ              NaN

# %%
review_train=pd.read_csv("Restaurant_reviews.csv")

# %%
review_train.shape
# Out:
# (1000, 2)

# %%
review_train.head(20)
# Out:
#                                                Review  Liked
# 0                            Wow... Loved this place.      1
# 1                                  Crust is not good.      0
# 2           Not tasty and the texture was just nasty.      0
# 3   Stopped by during the late May bank holiday of...      1
# 4   The selection on the menu was great and so wer...      1
# 5      Now I am getting angry and I want my damn pho.      0
# 6               Honeslty it didn't taste THAT fresh.)      0
# 7   The potatoes were like rubber and you could te...      0
# 8                           The fries were great too.      1
# 9                                      A great touch.      1
# 10                           Service was very prompt.      1
# 11                                 Would not go back.      0
# 12  The cashier had no care what so ever on what I...      0
# 13  I tried the Cape Cod ravoli, chicken, with cra...      1
# 14  I was disgusted because I was pretty sure that...      0
# 15  I was shocked because no signs indicate cash o...      0
# 16                                Highly recommended.      1
# 17             Waitress was a little slow in service.      0
# 18  This place is not worth your time, let alone V...      0
# 19                               did not like at all.      0

# %%
print("percentage for default \n")
print(round(review_train.Liked.value_counts(normalize=True)*100, 2))
round(review_train.Liked.value_counts(normalize=True)*100,2).plot(kind='bar')
plt.title("Percentage Distribution by review type")
plt.show()
# Out:
# percentage for default
#
# Liked
# 1    50.0
# 0    50.0
# Name: proportion, dtype: float64

# %%
review_train.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
#we will first remove brackets, numbers, punctuation and convert all cases to lower-case
def text_clean_1(text):
    text = text.lower()
    text = re.sub('', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text
cleaned1 = lambda x: text_clean_1(x)

# %%
review_train['cleaned_description'] = pd.DataFrame(review_train.Review.apply(cleaned1))
review_train.head(10)
# Out:
#                                               Review  Liked  \
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1
# 5     Now I am getting angry and I want my damn pho.      0
# 6              Honeslty it didn't taste THAT fresh.)      0
# 7  The potatoes were like rubber and you could te...      0
# 8                          The fries were great too.      1
# 9                                     A great touch.      1
#
#                                  cleaned_description
# 0                               wow loved this place
# 1                                  crust is not good
# 2           not tasty and the texture was just nasty
# 3  stopped by during the late may bank holiday of...
# 4  the selection on the menu was great and so wer...
# 5      now i am getting angry and i want my damn pho
# 6                 honeslty it didnt taste that fresh
# 7  the potatoes were like rubber and you could te...
# 8                           the fries were great too
# 9                                      a great touch

# %%
def text_clean2(text):
    text=re.sub('[‘’“”…]', '', text)
    text=re.sub('\n', '', text)
    return text
cleaned2=lambda x: text_clean2(x)

# %%
review_train['cleaned_new']=pd.DataFrame(review_train['cleaned_description'].apply(cleaned2))
review_train.head(10)
#NOW OUR DATA IS CLEAN
# Out:
#                                               Review  Liked  \
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1
# 5     Now I am getting angry and I want my damn pho.      0
# 6              Honeslty it didn't taste THAT fresh.)      0
# 7  The potatoes were like rubber and you could te...      0
# 8                          The fries were great too.      1
# 9                                     A great touch.      1
#
#                                  cleaned_description  \
# 0                               wow loved this place
# 1                                  crust is not good
# 2           not tasty and the texture was just nasty
# 3  stopped by during the late may bank holiday of...
# 4  the selection on the menu was great and so wer...
# 5      now i am getting angry and i want my damn pho
# 6                 honeslty it didnt taste that fresh
# 7  the potatoes were like rubber and you could te...
# 8                           the fries were great too
# 9                                      a great touch
#
#                                          cleaned_new
# 0                               wow loved this place
# 1                                  crust is not good
# 2           not tasty and the texture was just nasty
# 3  stopped by during the late may bank holiday of...
# 4  the selection on the menu was great and so wer...
# 5      now i am getting angry and i want my damn pho
# 6                 honeslty it didnt taste that fresh
# 7  the potatoes were like rubber and you could te...
# 8                           the fries were great too
# 9                                      a great touch

# %%
#Model Training
x=review_train['cleaned_new']
y=review_train['Liked']
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=10)

# %%
tvec = TfidfVectorizer()
clf2 = LogisticRegression(solver = "lbfgs")

# %%
model = Pipeline([('vectorizer',tvec),('classifier',clf2)])
model.fit(x_train, y_train)
predictions = model.predict(x_test)
confusion_matrix(predictions, y_test)
# Out:
# array([[81, 18],
#        [19, 82]], dtype=int64)

# %%
print("Accuracy:", accuracy_score(predictions, y_test))
print("Precision:", precision_score(predictions, y_test, average='weighted'))
print("Recall:", recall_score(predictions, y_test, average='weighted'))
# Out:
# Accuracy: 0.815
# Precision: 0.8150499999999999
# Recall: 0.815

# %%
a=["i hated it"]
result=model.predict(a)
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 a=["i hated it"]
# ----> 2 result=model.predict(a)
#       3 result
#
# NameError: name 'model' is not defined

# %%
write=pd.read_csv("cache_file.csv")
i=[]
for item in write['reviews']:    
    listt=item.split('&&&&&')
    count=0
    for j in listt:
        l=model.predict([j])
        count=count+l
    i.append(count/5) 
write.loc[:,'Sentiment Ratio']=i
write.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       5 count=0
#       6 for j in listt:
# ----> 7     l=model.predict([j])
#       8     count=count+l
#       9 i.append(count/5)
#
# NameError: name 'model' is not defined

# %%
arr=[]
with open("cache_file.csv", 'r',encoding='utf-8') as csvfile:
    datareader = csv.reader(csvfile)
    for row in datareader:
        arr.append(row)
print (arr)
# Out:
# [['name', 'vicinity', 'type', 'latitude', 'longitude', 'rating', 'reviews', 'place_id', 'Sentiment Ratio'], [], ['New Delhi', 'New Delhi', "['locality', 'political']", '28.6139298', '77.2088282', '', '[]', 'ChIJLbZ-NFv9DDkRzk0gTkm3wlI'], [], ['Manraj B&b', 'L 1/2, South Extension II, New Delhi', "['lodging', 'point_of_interest', 'establishment']", '28.57009109999999', '77.2193126', '', '[]', 'ChIJg3IIvF3iDDkRhZxTyMun76c'], [], ['Time Centre', '81-A, Khanna Market Road, Nehru Stadium, Lodi Colony, New Delhi', "['point_of_interest', 'store', 'establishment']", '28.5815944', '77.2203141', '', '[\'Very dishonest. Initially he told the price of 250 for battery replacement and at the time of payment he said 450. Dont go there. Pathetic guy. And that battery is for rs50.\', \'&&&&&\', \'Gave my antique clock to fix charged a lot but did a terrible job. Had to get it done all over again from a professional now it’s working smoothly. Would not trust them with expensive stuff.\', \'&&&&&\', \'Dont believe what this dude says. Without asking the price i gave 2 watch to replace battery. this chor charged 700 rupees. I checked the price, its only 20rs in amazon. Chor.\', \'&&&&&\', \'Its a shop located in Khanna Market Lodhi road , owner of the shop is very good. All types of watches are available as per your budget. I have bought watches from here several times.\', \'&&&&&\', "In simple don\'t trust his words, to sale his products he will say anything later he will be having all excuses to denied what he said.", \'&&&&&\']', 'ChIJ922KgfTiDDkRoMugs1Sykcw'], [], ['Deluxe Store', '41, Defence Colony, New Delhi', "['drugstore', 'department_store', 'health', 'point_of_interest', 'store', 'establishment']", '28.5735205', '77.2304928', '', "['It took them 5 mins to decide if they have peanuts or not. Inefficient staff.', '&&&&&', 'quality products', '&&&&&', 'Great place', '&&&&&', 'Deluxe store', '&&&&&', '', '&&&&&']", 'ChIJZ1LNSVfiDDkR2cVBaKkA9XU'], [], ['Softdot Education', 'K-16, Mahatma Gandhi Road, South Extension I, New Delhi', "['point_of_interest', 'establishment']", '28.5696119', '77.2180163', '', '[\'Fake institute, they are totally play with the career of student ( i lost my money and time very bad experience) Affiliated university are also fake i.e Mahatma Gandhi University, Meghalya. They are cheat the international student also my degree is not valid in my country also (institute & university both are fake) Indian government why support this type of study centers?\', \'&&&&&\', \'Fake institute. In 2014 I have done my graduation from them. Now, when I applied for my degree in University, they told me that degree is fake... They have wasted my 5 years, and that 3 yrs too.... I have them 25000 for the course. WORST INSTITUTE. And the comments given with 5 star, are all their employees..... WARNING! NEVER TAKE ADMISSION HERE !!!!!!!!!!!\', \'&&&&&\', \'i wasted 3 precious years of my life\\nand 20000 rupees fees and an advance 15000 rupees fees. some one should file a fir against the owner of this institute\\nthis is a scam.\', \'&&&&&\', "Pathetic services they guys are providing trust me I\'ve done my Hotel Management from Softdot institute 2014 and still I didn\'t get any marksheet  please refund my money I\'ve done police complaint also but no response from them\\nNow I\'m working with BPO just because of you guys #softdot sucks 🖕", \'&&&&&\', "Don\'t reach out to Softdot, the environment of Softdot is very bad as compare to other institute. No one respond in a proper manner now. So don\'t go for it.", \'&&&&&\']', 'ChIJqcjMwoMdDTkRlvx8423M8u8'], [], ['Skylink Suites', 'H, 7, South Extension I, South Delhi', "['lodging', 'point_of_interest', 'establishment']", '28.5713537', '77.2216006', '', '[\'Premium family hotel with excellent service and amenities. The spacious rooms along with the courteous staff make up the highlight of this property. The location is perfect for work and shopping visits.\\n\\nSpecial mention to Mr. Ajay P ...
