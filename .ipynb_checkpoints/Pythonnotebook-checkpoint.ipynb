# %%
import json
import os
import csv
import requests
import pprint
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import os.path
import joblib
from joblib import memory
from hmmlearn import hmm
import googlemaps 
import pandas as pd

# supress warnings
import warnings 
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
import re
import string
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
# Declaring API Keys Used
places_api_web_service =  'AIzaSyCztZNSls0oSkmLXe3FNjLilCA7xIp4Ork'
geocoding_api = 'AIzaSyA3cUamax65N5NLxuSF4EXuV6DGGMxDNXQ'

# %%
def latlong(loc1):
    current_loc = loc1.replace(" ", "+")

    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address=" + current_loc + "&key=" + geocoding_api

    response1 = requests.get(geocode_url)
    data = json.loads(response1.text)

    current_lat = data['results'][0]['geometry']['location']['lat']
    current_long = data['results'][0]['geometry']['location']['lng']
    return current_lat, current_long

# %%
# Declaring Global Variables Used
pause = 0.1
max_api_requests = 150000 
api_requests_count = 0
pp = pprint.PrettyPrinter(indent=4)

# %%
current_loc1 = input("Enter your user1 location as address: ")
current_loc2 = input("Enter your user2 location as address: ")
typ=input("Type of meeting place")
# Out:
# Enter your user1 location as address: Uttam nagar
# Enter your user2 location as address: noida
# Type of meeting place: cafe

# %%
# latlng="28.621271,77.061325"
# radius=5
radius = 3000
current_lat1,current_long1=latlong(current_loc1)
current_lat2,current_long2=latlong(current_loc2)
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="
if (api_requests_count < max_api_requests):  
    time.sleep(pause)
    api_requests_count += 1
    reverse_geocode_url = url + str((current_lat1+current_lat2)/2) + "," + str((current_long1+current_long2)/2)+ "&radius=" + str(radius) + "&type="+str(typ) + "&key=" + places_api_web_service
    response = requests.get(reverse_geocode_url)
    data = response.json().get("results",{})

# %%
if len(data) > 0:
        resp_address = data
        name = []
        types = []
        rating=[]
        lat=[]
        lng=[]
        rating=[]
        totnb_reviews=[]
        place_id_array=[]
        vicinity=[]
        review=[]
        
        
        for i in range (0, len(resp_address)):
            place_idd=resp_address[i]['place_id']
            params = {
            "place_id": place_idd,
            "key": 'AIzaSyCztZNSls0oSkmLXe3FNjLilCA7xIp4Ork',
            "fields": "reviews"  # Request specific fields to minimize data usage
            }
            base_url = "https://maps.googleapis.com/maps/api/place/details/json"
            response = requests.get(base_url, params=params)
            place_details = response.json().get("result", {})
            
            rat = place_details.get("rating")
            rating.append(rat)
            
            rev=place_details.get("reviews", [])
            revrat=[]
            for j in range(len(rev)):
                revrat.append(rev[j]['text'])
                revrat.append('&&&&&')
            review.append(revrat)
            
            place = gmaps.place(place_id=place_idd)
            name.append(str(resp_address[i]['name']))
            types.append (resp_address[i]['types'])
            lat.append(resp_address[i]['geometry']['location']['lat'])
            lng.append (resp_address[i]['geometry']['location']['lng'])
            place_id_array.append(place_idd)
            vicinity.append (resp_address[i]['vicinity'])

# %%
with open('cache_file.csv', 'w',encoding='utf-8') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    heading = ["name","vicinity", "type",'latitude','longitude','rating','reviews','place_id','Sentiment Ratio']
    wr.writerow(heading)
    for i in range(len(types)):
        wr.writerow([name[i],vicinity[i],types[i],lat[i],lng[i],rating[i],review[i],place_id_array[i]])
myfile.close()

# %%
write=pd.read_csv('cache_file.csv')
write.head(20)
# Out:
#                                name  \
# 0       Shalom / Laidback Cafe GK-1
# 1                       Street Cafe
# 2                Ping's Cafe Orient
# 3                        Cafe Brook
# 4              Sleepy Owl Coffee HQ
# 5                 Meraki Cafe & Bar
# 6                             1 Oak
# 7                  Daily Grind Cafe
# 8                       Coffee Bond
# 9   Portraits Maker Sketch For Gift
# 10         Novelty Dairy and Stores
# 11                   Out of the Box
# 12                      Latitude 28
# 13             SodaBottleOpenerWala
# 14                  Café Coffee Day
# 15                  Mad Over Donuts
# 16                   Big Chill Cafe
# 17                 The Game Of Buns
# 18                Yellow Brick Road
# 19           Garage Inc., New Delhi
#
#                                              vicinity  \
# 0   N-17, N Block Market, Greater Kailash I, New D...
# 1         D 49, South Extension I, Block D, New Delhi
# 2   13, Puran Chand Yogi Marg, Lodi Colony, New Delhi
# 3   AIIMS Campus Temple, Gents Hostel 6 and Gym La...
# 4   74, Link Road, Lajpat Nagar III, Lajpat Nagar,...
# 5   DDA Complex, C 43-44-45, Defence Colony, New D...
# 6   near Moolchand Metro Station, Shop No 49 50 La...
# 7     Ansal Plaza, C Block, Khel Gaon Marg, New Delhi
# 8   Shop No. 4 Local Shopping Complex, South Exten...
# 9   P-2 First Floor, Pilanji, Sarojini Nagar, New ...
# 10  Shop No. 43, Birbal Road, Opp. Post Office, Ju...
# 11              5, Khan Market, Rabindra Nagar, Delhi
# 12  above The Goodearth Store, Shop No. 9, Second ...
# 13        73B, Khan Market, Rabindra Nagar, New Delhi
# 14                             24, Khan Market, Delhi
# 15  K-96B, Block K, Lajpat Nagar II, Jal Vihar, Ne...
# 16         35, Khan Market, Rabindra Nagar, New Delhi
# 17  C-6, Back Side, Amar Colony, Lajpat Nagar 4, N...
# 18  Subramania Bharti Marg, Sujan Singh Park, New ...
# 19  Uphaar Cinema Complex, Market Complex, R7 B, G...
#
#                                                  type   latitude  longitude  \
# 0   ['restaurant', 'cafe', 'bar', 'night_club', 'f...  28.556408  77.232919
# 1   ['cafe', 'restaurant', 'food', 'point_of_inter...  28.572888  77.220929
# 2   ['restaurant', 'cafe', 'food', 'point_of_inter...  28.583606  77.223289
# 3   ['cafe', 'store', 'food', 'point_of_interest',...  28.567088  77.213045
# 4   ['cafe', 'store', 'food', 'point_of_interest',...  28.568294  77.235536
# 5   ['cafe', 'bar', 'restaurant', 'food', 'point_o...  28.566569  77.233918
# 6   ['cafe', 'bar', 'restaurant', 'food', 'point_o...  28.566459  77.233874
# 7   ['cafe', 'food', 'point_of_interest', 'establi...  28.562242  77.224608
# 8   ['cafe', 'store', 'restaurant', 'food', 'point...  28.560403  77.218072
# 9   ['art_gallery', 'cafe', 'store', 'food', 'poin...  28.579798  77.201295
# 10  ['cafe', 'restaurant', 'food', 'point_of_inter...  28.583717  77.243863
# 11  ['restaurant', 'cafe', 'bar', 'store', 'food',...  28.599719  77.226145
# 12  ['cafe', 'bar', 'store', 'restaurant', 'food',...  28.599548  77.226376
# 13  ['cafe', 'restaurant', 'food', 'point_of_inter...  28.600075  77.226235
# 14  ['cafe', 'store', 'food', 'point_of_interest',...  28.600199  77.227315
# 15  ['cafe', 'bakery', 'store', 'restaurant', 'foo...  28.567237  77.246476
# 16  ['cafe', 'store', 'restaurant', 'food', 'point...  28.600592  77.227579
# 17  ['cafe', 'food', 'point_of_interest', 'establi...  28.562731  77.244728
# 18  ['cafe', 'store', 'restaurant', 'food', 'point...  28.601787  77.229080
# 19  ['cafe', 'bar', 'restaurant', 'food', 'point_o...  28.557370  77.205013
#
#     rating                                            reviews  \
# 0      NaN  ['Visited laid back cafe at GK1 on Sunday, 13 ...
# 1      NaN  ['Loved the place.... Good for take aways but ...
# 2      NaN  ["First of all this is not a fine dining, its ...
# 3      NaN  ['"AIIMS Cafe, open 24 hrs, offers convenience...
# 4      NaN  ['Being a coffee lover, I love trying new coff...
# 5      NaN  ['Awesome atmosphere and foods .\n\nThey have ...
# 6      NaN  ['Visited this cafe on a Friday night and enjo...
# 7      NaN  ['For Dat Daily Grind doe', '&&&&&', '', '&&&&...
# 8      NaN  ["Visited on a cold Sunday late afternoon. The...
# 9      NaN  ['Working with the professional sketch artist ...
# 10     NaN  ["Living at Jangpura Extension for many years ...
# 11     NaN  ['Amazing food with beautiful ambiance. I lite...
# 12     NaN  ['I enjoyed the restaurant! It’s on the second...
# 13     NaN  ['Tried Parsi cuisine for the very first time ...
# 14     NaN  ['This branch is everything I expect from CCD ...
# 15     NaN  ['Excellent food..delicious donuts ...highly r...
# 16     NaN  ['Interesting place to eat in Khan Market in N...
# 17     NaN  ['They serve the most tasteless food. Even a 1...
# 18     NaN  ['Had our new years day breakfast at YBR. Pret...
# 19     NaN  ["Man!! You really gotta visit this place for ...
#
#                        place_id  Sentiment Ratio
# 0   ChIJD2nDu7jjDDkRXTDRNrJuEO4              NaN
# 1   ChIJDzl1j17iDDkR2V-LbHjDcSo              NaN
# 2   ChIJCWkUAfTiDDkRDPqIZjWQM00              NaN
# 3   ChIJ7Qcya2biDDkRDhIcHAe2yGo              NaN
# 4   ChIJsUCFLRTiDDkR7dUO_nU3euI              NaN
# 5   ChIJwZGQEU7iDDkRU08UBDrU7_0              NaN
# 6   ChIJFypRFE7iDDkRbolC774I4FA              NaN
# 7   ChIJs0O2QUTiDDkRly9oXT-n3OE              NaN
# 8   ChIJq02ZAkLiDDkR3uW_sM7pvF0              NaN
# 9   ChIJsxL3zobiDDkRYIIML0OX4io              NaN
# 10  ChIJp88QDwHjDDkRxQ60w6g0sVw              NaN
# 11  ChIJAbM0teniDDkR3tszjDvd0kw              NaN
# 12  ChIJ17ixS-jiDDkRXjIzR6OYIUk              NaN
# 13  ChIJf9jpNOjiDDkRk0v5w-4zpMA              NaN
# 14  ChIJB4XqPujiDDkRm3sX-qvyH44              NaN
# 15  ChIJYXOcq7PjDDkRnAk4FF9dJew              NaN
# 16  ChIJlbC2F-jiDDkR0QjzcgI9B0I              NaN
# 17  ChIJX6UnjrTjDDkRxxiGuHwEKo8              NaN
# 18  ChIJE_sfpcLiDDkRP5MvLop9SFU              NaN
# 19  ChIJ-0_jYHXiDDkRlKfWn39CGfk              NaN

# %%
review_train=pd.read_csv("Restaurant_reviews.csv")

# %%
review_train.shape
# Out:
# (1000, 2)

# %%
review_train.head(20)
# Out:
#                                                Review  Liked
# 0                            Wow... Loved this place.      1
# 1                                  Crust is not good.      0
# 2           Not tasty and the texture was just nasty.      0
# 3   Stopped by during the late May bank holiday of...      1
# 4   The selection on the menu was great and so wer...      1
# 5      Now I am getting angry and I want my damn pho.      0
# 6               Honeslty it didn't taste THAT fresh.)      0
# 7   The potatoes were like rubber and you could te...      0
# 8                           The fries were great too.      1
# 9                                      A great touch.      1
# 10                           Service was very prompt.      1
# 11                                 Would not go back.      0
# 12  The cashier had no care what so ever on what I...      0
# 13  I tried the Cape Cod ravoli, chicken, with cra...      1
# 14  I was disgusted because I was pretty sure that...      0
# 15  I was shocked because no signs indicate cash o...      0
# 16                                Highly recommended.      1
# 17             Waitress was a little slow in service.      0
# 18  This place is not worth your time, let alone V...      0
# 19                               did not like at all.      0

# %%
print("percentage for default \n")
print(round(review_train.Liked.value_counts(normalize=True)*100, 2))
round(review_train.Liked.value_counts(normalize=True)*100,2).plot(kind='bar')
plt.title("Percentage Distribution by review type")
plt.show()
# Out:
# percentage for default
#
# 1    50.0
# 0    50.0
# Name: Liked, dtype: float64

# %%
review_train.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
#we will first remove brackets, numbers, punctuation and convert all cases to lower-case
def text_clean_1(text):
    text = text.lower()
    text = re.sub('', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text
cleaned1 = lambda x: text_clean_1(x)

# %%
review_train['cleaned_description'] = pd.DataFrame(review_train.Review.apply(cleaned1))
review_train.head(10)
# Out:
#                                               Review  Liked  \
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1
# 5     Now I am getting angry and I want my damn pho.      0
# 6              Honeslty it didn't taste THAT fresh.)      0
# 7  The potatoes were like rubber and you could te...      0
# 8                          The fries were great too.      1
# 9                                     A great touch.      1
#
#                                  cleaned_description
# 0                               wow loved this place
# 1                                  crust is not good
# 2           not tasty and the texture was just nasty
# 3  stopped by during the late may bank holiday of...
# 4  the selection on the menu was great and so wer...
# 5      now i am getting angry and i want my damn pho
# 6                 honeslty it didnt taste that fresh
# 7  the potatoes were like rubber and you could te...
# 8                           the fries were great too
# 9                                      a great touch

# %%
def text_clean2(text):
    text=re.sub('[‘’“”…]', '', text)
    text=re.sub('\n', '', text)
    return text
cleaned2=lambda x: text_clean2(x)

# %%
review_train['cleaned_new']=pd.DataFrame(review_train['cleaned_description'].apply(cleaned2))
review_train.head(10)
#NOW OUR DATA IS CLEAN
# Out:
#                                               Review  Liked  \
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1
# 5     Now I am getting angry and I want my damn pho.      0
# 6              Honeslty it didn't taste THAT fresh.)      0
# 7  The potatoes were like rubber and you could te...      0
# 8                          The fries were great too.      1
# 9                                     A great touch.      1
#
#                                  cleaned_description  \
# 0                               wow loved this place
# 1                                  crust is not good
# 2           not tasty and the texture was just nasty
# 3  stopped by during the late may bank holiday of...
# 4  the selection on the menu was great and so wer...
# 5      now i am getting angry and i want my damn pho
# 6                 honeslty it didnt taste that fresh
# 7  the potatoes were like rubber and you could te...
# 8                           the fries were great too
# 9                                      a great touch
#
#                                          cleaned_new
# 0                               wow loved this place
# 1                                  crust is not good
# 2           not tasty and the texture was just nasty
# 3  stopped by during the late may bank holiday of...
# 4  the selection on the menu was great and so wer...
# 5      now i am getting angry and i want my damn pho
# 6                 honeslty it didnt taste that fresh
# 7  the potatoes were like rubber and you could te...
# 8                           the fries were great too
# 9                                      a great touch

# %%
#Model Training
x=review_train['cleaned_new']
y=review_train['Liked']
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=10)

# %%
tvec = TfidfVectorizer()
clf2 = LogisticRegression(solver = "lbfgs")

# %%
model = Pipeline([('vectorizer',tvec),('classifier',clf2)])
model.fit(x_train, y_train)
predictions = model.predict(x_test)
confusion_matrix(predictions, y_test)
# Out:
# array([[81, 18],
#        [19, 82]], dtype=int64)

# %%
print("Accuracy:", accuracy_score(predictions, y_test))
print("Precision:", precision_score(predictions, y_test, average='weighted'))
print("Recall:", recall_score(predictions, y_test, average='weighted'))
# Out:
# Accuracy: 0.815
# Precision: 0.8150499999999999
# Recall: 0.815

# %%
a=["i'm  happy"]
result=model.predict(a)
result
# Out:
# array([1], dtype=int64)

# %%
write=pd.read_csv("cache_file.csv")
i=[]
for item in write['reviews']:    
    listt=item.split('&&&&&')
    count=0
    for j in listt:
        l=model.predict([j])
        count=count+l
    i.append(count/5) 
write.loc[:,'Sentiment Ratio']=i

write.head(20)
# Out:
#                                name  \
# 0       Shalom / Laidback Cafe GK-1
# 1                       Street Cafe
# 2                Ping's Cafe Orient
# 3                        Cafe Brook
# 4              Sleepy Owl Coffee HQ
# 5                 Meraki Cafe & Bar
# 6                             1 Oak
# 7                  Daily Grind Cafe
# 8                       Coffee Bond
# 9   Portraits Maker Sketch For Gift
# 10         Novelty Dairy and Stores
# 11                   Out of the Box
# 12                      Latitude 28
# 13             SodaBottleOpenerWala
# 14                  Café Coffee Day
# 15                  Mad Over Donuts
# 16                   Big Chill Cafe
# 17                 The Game Of Buns
# 18                Yellow Brick Road
# 19           Garage Inc., New Delhi
#
#                                              vicinity  \
# 0   N-17, N Block Market, Greater Kailash I, New D...
# 1         D 49, South Extension I, Block D, New Delhi
# 2   13, Puran Chand Yogi Marg, Lodi Colony, New Delhi
# 3   AIIMS Campus Temple, Gents Hostel 6 and Gym La...
# 4   74, Link Road, Lajpat Nagar III, Lajpat Nagar,...
# 5   DDA Complex, C 43-44-45, Defence Colony, New D...
# 6   near Moolchand Metro Station, Shop No 49 50 La...
# 7     Ansal Plaza, C Block, Khel Gaon Marg, New Delhi
# 8   Shop No. 4 Local Shopping Complex, South Exten...
# 9   P-2 First Floor, Pilanji, Sarojini Nagar, New ...
# 10  Shop No. 43, Birbal Road, Opp. Post Office, Ju...
# 11              5, Khan Market, Rabindra Nagar, Delhi
# 12  above The Goodearth Store, Shop No. 9, Second ...
# 13        73B, Khan Market, Rabindra Nagar, New Delhi
# 14                             24, Khan Market, Delhi
# 15  K-96B, Block K, Lajpat Nagar II, Jal Vihar, Ne...
# 16         35, Khan Market, Rabindra Nagar, New Delhi
# 17  C-6, Back Side, Amar Colony, Lajpat Nagar 4, N...
# 18  Subramania Bharti Marg, Sujan Singh Park, New ...
# 19  Uphaar Cinema Complex, Market Complex, R7 B, G...
#
#                                                  type   latitude  longitude  \
# 0   ['restaurant', 'cafe', 'bar', 'night_club', 'f...  28.556408  77.232919
# 1   ['cafe', 'restaurant', 'food', 'point_of_inter...  28.572888  77.220929
# 2   ['restaurant', 'cafe', 'food', 'point_of_inter...  28.583606  77.223289
# 3   ['cafe', 'store', 'food', 'point_of_interest',...  28.567088  77.213045
# 4   ['cafe', 'store', 'food', 'point_of_interest',...  28.568294  77.235536
# 5   ['cafe', 'bar', 'restaurant', 'food', 'point_o...  28.566569  77.233918
# 6   ['cafe', 'bar', 'restaurant', 'food', 'point_o...  28.566459  77.233874
# 7   ['cafe', 'food', 'point_of_interest', 'establi...  28.562242  77.224608
# 8   ['cafe', 'store', 'restaurant', 'food', 'point...  28.560403  77.218072
# 9   ['art_gallery', 'cafe', 'store', 'food', 'poin...  28.579798  77.201295
# 10  ['cafe', 'restaurant', 'food', 'point_of_inter...  28.583717  77.243863
# 11  ['restaurant', 'cafe', 'bar', 'store', 'food',...  28.599719  77.226145
# 12  ['cafe', 'bar', 'store', 'restaurant', 'food',...  28.599548  77.226376
# 13  ['cafe', 'restaurant', 'food', 'point_of_inter...  28.600075  77.226235
# 14  ['cafe', 'store', 'food', 'point_of_interest',...  28.600199  77.227315
# 15  ['cafe', 'bakery', 'store', 'restaurant', 'foo...  28.567237  77.246476
# 16  ['cafe', 'store', 'restaurant', 'food', 'point...  28.600592  77.227579
# 17  ['cafe', 'food', 'point_of_interest', 'establi...  28.562731  77.244728
# 18  ['cafe', 'store', 'restaurant', 'food', 'point...  28.601787  77.229080
# 19  ['cafe', 'bar', 'restaurant', 'food', 'point_o...  28.557370  77.205013
#
#     rating                                            reviews  \
# 0      NaN  ['Visited laid back cafe at GK1 on Sunday, 13 ...
# 1      NaN  ['Loved the place.... Good for take aways but ...
# 2      NaN  ["First of all this is not a fine dining, its ...
# 3      NaN  ['"AIIMS Cafe, open 24 hrs, offers convenience...
# 4      NaN  ['Being a coffee lover, I love trying new coff...
# 5      NaN  ['Awesome atmosphere and foods .\n\nThey have ...
# 6      NaN  ['Visited this cafe on a Friday night and enjo...
# 7      NaN  ['For Dat Daily Grind doe', '&&&&&', '', '&&&&...
# 8      NaN  ["Visited on a cold Sunday late afternoon. The...
# 9      NaN  ['Working with the professional sketch artist ...
# 10     NaN  ["Living at Jangpura Extension for many years ...
# 11     NaN  ['Amazing food with beautiful ambiance. I lite...
# 12     NaN  ['I enjoyed the restaurant! It’s on the second...
# 13     NaN  ['Tried Parsi cuisine for the very first time ...
# 14     NaN  ['This branch is everything I expect from CCD ...
# 15     NaN  ['Excellent food..delicious donuts ...highly r...
# 16     NaN  ['Interesting place to eat in Khan Market in N...
# 17     NaN  ['They serve the most tasteless food. Even a 1...
# 18     NaN  ['Had our new years day breakfast at YBR. Pret...
# 19     NaN  ["Man!! You really gotta visit this place for ...
#
#                        place_id  Sentiment Ratio
# 0   ChIJD2nDu7jjDDkRXTDRNrJuEO4              1.0
# 1   ChIJDzl1j17iDDkR2V-LbHjDcSo              1.0
# 2   ChIJCWkUAfTiDDkRDPqIZjWQM00              0.8
# 3   ChIJ7Qcya2biDDkRDhIcHAe2yGo              0.8
# 4   ChIJsUCFLRTiDDkR7dUO_nU3euI              0.6
# 5   ChIJwZGQEU7iDDkRU08UBDrU7_0              0.8
# 6   ChIJFypRFE7iDDkRbolC774I4FA              1.0
# 7   ChIJs0O2QUTiDDkRly9oXT-n3OE              0.0
# 8   ChIJq02ZAkLiDDkR3uW_sM7pvF0              0.8
# 9   ChIJsxL3zobiDDkRYIIML0OX4io              0.4
# 10  ChIJp88QDwHjDDkRxQ60w6g0sVw              0.8
# 11  ChIJAbM0teniDDkR3tszjDvd0kw              1.0
# 12  ChIJ17ixS-jiDDkRXjIzR6OYIUk              1.0
# 13  ChIJf9jpNOjiDDkRk0v5w-4zpMA              1.0
# 14  ChIJB4XqPujiDDkRm3sX-qvyH44              1.0
# 15  ChIJYXOcq7PjDDkRnAk4FF9dJew              0.4
# 16  ChIJlbC2F-jiDDkR0QjzcgI9B0I              1.0
# 17  ChIJX6UnjrTjDDkRxxiGuHwEKo8              0.0
# 18  ChIJE_sfpcLiDDkRP5MvLop9SFU              0.8
# 19  ChIJ-0_jYHXiDDkRlKfWn39CGfk              1.0
